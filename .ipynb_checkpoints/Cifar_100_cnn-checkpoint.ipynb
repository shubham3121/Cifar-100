# %% [markdown]
# # CIFAR - 100

# %% [markdown]
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.

# %% [markdown]
# ### Load CIFAR-100 Database

# %%
import keras
from keras.datasets import cifar100

# Import train and test data
(X_train, y_train),(X_test, y_test) = cifar100.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from http://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 168820736/169001437 [============================>.] - ETA: 0s

# %% [markdown]
# ### Visualizing Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20, 5))
for i in range(25):
    ax = fig.add_subplot(3, 12, i+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(X_train[i]))

# %% [markdown]
# ### Rescale Images by dividing each pixel in every Image by 255

# %%
# Rescale [0,255] --> [0, 1]
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

# %%
from keras.utils import np_utils

# One-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# Dividing training set into training and validation sets
(X_train, X_valid) = X_train[5000:], X_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print the shape of training set
print('X_train shape:', X_train.shape)

# print number of training, validation, and test images
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
print(X_valid.shape[0], 'validation samples')
# Out:
# X_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.optimizers import SGD

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_34 (Conv2D)           (None, 32, 32, 32)        416
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 32, 32, 32)        4128
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 16, 16, 64)        8256
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 16, 16, 64)        16448
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               2097664
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 100)               51300
# =================================================================
# Total params: 2,178,212
# Trainable params: 2,178,212
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the model

# %%
# compile the model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %% [markdown]
# ### Train the model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, save_best_only=True)
hist = model.fit(X_train, y_train, batch_size=128, epochs=20,validation_data=(X_valid, y_valid), 
                 callbacks=[checkpointer], verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/20
# Epoch 00000: val_loss improved from inf to 4.32531, saving model to model.weights.best.hdf5
# 11s - loss: 4.5426 - acc: 0.0209 - val_loss: 4.3253 - val_acc: 0.0524
# Epoch 2/20
# Epoch 00001: val_loss improved from 4.32531 to 3.85020, saving model to model.weights.best.hdf5
# 11s - loss: 4.1165 - acc: 0.0734 - val_loss: 3.8502 - val_acc: 0.1180
# Epoch 3/20
# Epoch 00002: val_loss improved from 3.85020 to 3.75230, saving model to model.weights.best.hdf5
# 11s - loss: 3.8356 - acc: 0.1131 - val_loss: 3.7523 - val_acc: 0.1362
# Epoch 4/20
# Epoch 00003: val_loss improved from 3.75230 to 3.48032, saving model to model.weights.best.hdf5
# 11s - loss: 3.6524 - acc: 0.1424 - val_loss: 3.4803 - val_acc: 0.1756
# Epoch 5/20
# Epoch 00004: val_loss improved from 3.48032 to 3.36050, saving model to model.weights.best.hdf5
# 11s - loss: 3.4762 - acc: 0.1743 - val_loss: 3.3605 - val_acc: 0.1978
# Epoch 6/20
# Epoch 00005: val_loss improved from 3.36050 to 3.10651, saving model to model.weights.best.hdf5
# 11s - loss: 3.3070 - acc: 0.2051 - val_loss: 3.1065 - val_acc: 0.2434
# Epoch 7/20
# Epoch 00006: val_loss improved from 3.10651 to 2.97246, saving model to model.weights.best.hdf5
# 11s - loss: 3.1452 - acc: 0.2321 - val_loss: 2.9725 - val_acc: 0.2708
# Epoch 8/20
# Epoch 00007: val_loss improved from 2.97246 to 2.87100, saving model to model.weights.best.hdf5
# 11s - loss: 3.0198 - acc: 0.2592 - val_loss: 2.8710 - val_acc: 0.2854
# Epoch 9/20
# Epoch 00008: val_loss improved from 2.87100 to 2.78725, saving model to model.weights.best.hdf5
# 11s - loss: 2.9076 - acc: 0.2786 - val_loss: 2.7872 - val_acc: 0.3126
# Epoch 10/20
# Epoch 00009: val_loss improved from 2.78725 to 2.72495, saving model to model.weights.best.hdf5
# 11s - loss: 2.7937 - acc: 0.2995 - val_loss: 2.7250 - val_acc: 0.3268
# Epoch 11/20
# Epoch 00010: val_loss improved from 2.72495 to 2.62371, saving model to model.weights.best.hdf5
# 11s - loss: 2.7062 - acc: 0.3151 - val_loss: 2.6237 - val_acc: 0.3384
# Epoch 12/20
# Epoch 00011: val_loss improved from 2.62371 to 2.56481, saving model to model.weights.best.hdf5
# 11s - loss: 2.6057 - acc: 0.3352 - val_loss: 2.5648 - val_acc: 0.3484
# Epoch 13/20
# Epoch 00012: val_loss improved from 2.56481 to 2.52390, saving model to model.weights.best.hdf5
# 11s - loss: 2.5186 - acc: 0.3551 - val_loss: 2.5239 - val_acc: 0.3562
# Epoch 14/20
# Epoch 00013: val_loss improved from 2.52390 to 2.40161, saving model to model.weights.best.hdf5
# 11s - loss: 2.4526 - acc: 0.3676 - val_loss: 2.4016 - val_acc: 0.3842
# Epoch 15/20
# Epoch 00014: val_loss improved from 2.40161 to 2.38938, saving model to model.weights.best.hdf5
# 11s - loss: 2.3818 - acc: 0.3791 - val_loss: 2.3894 - val_acc: 0.3798
# Epoch 16/20
# Epoch 00015: val_loss improved from 2.38938 to 2.34476, saving model to model.weights.best.hdf5
# 11s - loss: 2.3064 - acc: 0.3986 - val_loss: 2.3448 - val_acc: 0.3978
# Epoch 17/20
# Epoch 00016: val_loss improved from 2.34476 to 2.34075, saving model to model.weights.best.hdf5
# 11s - loss: 2.2471 - acc: 0.4110 - val_loss: 2.3407 - val_acc: 0.3898
# Epoch 18/20
# Epoch 00017: val_loss improved from 2.34075 to 2.32303, saving model to model.weights.best.hdf5
# 11s - loss: 2.1934 - acc: 0.4203 - val_loss: 2.3230 - val_acc: 0.3996
# Epoch 19/20
# Epoch 00018: val_loss improved from 2.32303 to 2.26010, saving model to model.weights.best.hdf5
# 11s - loss: 2.1339 - acc: 0.4364 - val_loss: 2.2601 - val_acc: 0.4060
# Epoch 20/20
# Epoch 00019: val_loss did not improve
# 11s - loss: 2.0817 - acc: 0.4451 - val_loss: 2.2670 - val_acc: 0.4038

# %% [markdown]
# ### Load the model with the best accuracy

# %%
# load the weights of the model with best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### Calculate Classificaition Accuracy on Test Set

# %%
# Score trained model
score = model.evaluate(X_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.4342
